# %%
import pandas as pd

# %%
results_fiw_v3 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_fiw_v3.csv")
results_fiw_v4 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_fiw_v4.csv")
results_thws_v3 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_thws_v3.csv")
results_thws_v4 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_thws_v4.csv")
results_fiw_v4_gemini_mix_DC10_KG3 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_fiw_v4_gemini_mix_DC10_KG3.csv")
results_fiw_v4_gemini_naive_DC10 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_fiw_v4_gemini_naive_DC10.csv")

# %% [markdown]
# ## FIW

# %%
results_fiw_v3[:100].describe()
# Out:
#        genauigkeit          F1        BLEU  factual_correctness  \
# count   100.000000  100.000000  100.000000            100.00000
# mean      0.500000    0.142539    0.074839              0.28800
# std       0.502519    0.125276    0.157636              0.29532
# min       0.000000    0.000000    0.000000              0.00000
# 25%       0.000000    0.056902    0.016533              0.00000
# 50%       0.500000    0.107387    0.028428              0.25000
# 75%       1.000000    0.219829    0.054067              0.50000
# max       1.000000    0.727273    1.000000              1.00000
#
#        semantic_similarity
# count           100.000000
# mean              0.491217
# std               0.140733
# min               0.206292
# 25%               0.386433
# 50%               0.480128
# 75%               0.591745
# max               0.867627

# %%
results_fiw_v4[:100].describe()
# Out:
#        genauigkeit          F1        BLEU  factual_correctness  \
# count   100.000000  100.000000  100.000000           100.000000
# mean      0.540000    0.129402    0.054455             0.286700
# std       0.500908    0.128362    0.121733             0.309101
# min       0.000000    0.000000    0.000000             0.000000
# 25%       0.000000    0.036782    0.011461             0.000000
# 50%       1.000000    0.098124    0.021930             0.235000
# 75%       1.000000    0.178788    0.036768             0.562500
# max       1.000000    0.727273    1.000000             1.000000
#
#        semantic_similarity
# count           100.000000
# mean              0.476461
# std               0.137688
# min               0.179942
# 25%               0.375049
# 50%               0.469017
# 75%               0.537388
# max               0.862269

# %%
results_fiw_v4_gemini_mix_DC10_KG3.describe()
# Out:
#        genauigkeit          F1        BLEU  factual_correctness  \
# count   100.000000  100.000000  100.000000           100.000000
# mean      0.660000    0.141153    0.060913             0.297500
# std       0.476095    0.108707    0.134816             0.314001
# min       0.000000    0.000000    0.000000             0.000000
# 25%       0.000000    0.058943    0.010643             0.000000
# 50%       1.000000    0.120644    0.019284             0.235000
# 75%       1.000000    0.193020    0.048353             0.512500
# max       1.000000    0.585366    1.000000             1.000000
#
#        semantic_similarity  duration_seconds
# count           100.000000        100.000000
# mean              0.485434          5.324300
# std               0.138609          1.123183
# min               0.156054          3.840000
# 25%               0.379395          4.617500
# 50%               0.465793          5.035000
# 75%               0.589782          5.812500
# ...

# %%
results_fiw_v4_gemini_naive_DC10.describe()
# Out:
#        genauigkeit          F1        BLEU  factual_correctness  \
# count   100.000000  100.000000  100.000000            100.00000
# mean      0.470000    0.108031    0.056921              0.21500
# std       0.501614    0.107288    0.129295              0.29414
# min       0.000000    0.000000    0.000000              0.00000
# 25%       0.000000    0.000000    0.015757              0.00000
# 50%       0.000000    0.083333    0.026187              0.00000
# 75%       1.000000    0.158421    0.030891              0.38500
# max       1.000000    0.458333    1.000000              1.00000
#
#        semantic_similarity  duration_seconds
# count           100.000000        100.000000
# mean              0.460151          2.575200
# std               0.142106          1.037403
# min               0.168549          1.700000
# 25%               0.362358          2.007500
# 50%               0.441870          2.250000
# 75%               0.536797          2.760000
# ...

# %%
print(results_fiw_v4_gemini_mix_DC10_KG3[results_fiw_v4_gemini_mix_DC10_KG3["factual_correctness"]==1].count())
# Out:
# question               3
# bot_answer             3
# gold_answer            3
# genauigkeit            3
# F1                     3
# BLEU                   3
# factual_correctness    3
# semantic_similarity    3
# duration_seconds       3
# dtype: int64

# %% [markdown]
# ## THWS

# %%
results_thws_v3.describe()
# Out:
#        genauigkeit         F1       BLEU  factual_correctness  \
# count    99.000000  99.000000  99.000000            99.000000
# mean      0.353535   0.058460   0.028565             0.121414
# std       0.480500   0.077740   0.035924             0.257535
# min       0.000000   0.000000   0.000000             0.000000
# 25%       0.000000   0.000000   0.004638             0.000000
# 50%       0.000000   0.033898   0.024342             0.000000
# 75%       1.000000   0.101019   0.033969             0.060000
# max       1.000000   0.377778   0.204480             1.000000
#
#        semantic_similarity
# count            99.000000
# mean              0.312258
# std               0.185975
# min              -0.056712
# 25%               0.193855
# 50%               0.326517
# 75%               0.428571
# max               0.825582

# %%
results_thws_v4.describe()
# Out:
#        genauigkeit         F1       BLEU  factual_correctness  \
# count    99.000000  99.000000  99.000000            99.000000
# mean      0.595960   0.110326   0.069425             0.266364
# std       0.493203   0.139038   0.136171             0.320607
# min       0.000000   0.000000   0.000000             0.000000
# 25%       0.000000   0.000000   0.002261             0.000000
# 50%       1.000000   0.082474   0.017902             0.170000
# 75%       1.000000   0.140394   0.048573             0.490000
# max       1.000000   0.677419   0.617651             1.000000
#
#        semantic_similarity
# count            99.000000
# mean              0.399912
# std               0.241326
# min               0.034809
# 25%               0.227721
# 50%               0.421486
# 75%               0.588707
# max               0.922372

# %%
df1 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_2025-08-28_15-00-39_fiw_v4_1.csv")
df2 = pd.read_csv("/Users/lelange/Uni/askTHWS/test_results/results_2025-08-29_11-05-55_fiw_v4_2.csv")

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
display(df.head())
# Out:
#                                             question  \
# 0    Welche Studiengänge bietet die THWS aktuell an?
# 1  Gibt es eine Zulassungsbeschränkung für den St...
# 2  Wie lange dauert das Studium der Wirtschaftsin...
# 3  In welcher Sprache wird der Studiengang Wirtsc...
# 4  Wie viele ECTS-Punkte müssen im Studium Wirtsc...
#
#                                           bot_answer  \
# 0  Die THWS bietet eine Kombination aus Theorie u...
# 1  Für die Zulassung in zulassungsbeschränkten Ba...
# 2  Ich konnte keine passenden Informationen zu Ih...
# 3  Der Studiengang Wirtschaftsingenieurwesen und ...
# 4  Um frühestens mit der Bearbeitung der Bachelor...
#
#                                          gold_answer  genauigkeit        F1  \
# 0  Aktuell bietet die THWS folgende Studiengänge ...            0  0.068182
# 1  Nein, der Studiengang Wirtschaftsinformatik is...            0  0.022989
# 2  Das Vollzeitstudium Wirtschaftsinformatik daue...            0  0.000000
# ...

# %%
df.to_csv("results_fiw_v4.csv", index=False)
