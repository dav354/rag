# %%
import pandas as pd

# %%
df_4B = pd.read_csv("/Users/lelange/Uni/askTHWS/testing/aspect_critic_test/eval_results/results_4B_2025-07-13.csv")
df_12B = pd.read_csv("/Users/lelange/Uni/askTHWS/testing/aspect_critic_test/eval_results/results_12B_2025-07-13.csv")
df_27B = pd.read_csv("/Users/lelange/Uni/askTHWS/testing/aspect_critic_test/eval_results/results_27B_2025-07-13.csv")

# %%
print(df_4B["correctness"].sum())
# Out:
# 36.0

# %%
print(df_12B["correctness"].sum())
# Out:
# 43

# %%
print(df_27B["correctness"].sum())
# Out:
# 46

# %%
display(df_4B.head()[['question', 'ref_answer']])
# Out:
#                                             question  \
# 0    Welche Studiengänge bietet die THWS aktuell an?
# 1  Gibt es eine Zulassungsbeschränkung für den St...
# 2  Wie lange dauert das Studium der Wirtschaftsin...
# 3  In welcher Sprache wird der Studiengang Wirtsc...
# 4  Wie viele ECTS-Punkte müssen im Studium Wirtsc...
#
#                                           ref_answer
# 0  Aktuell bietet die THWS folgende Studiengänge ...
# 1  Nein, der Studiengang Wirtschaftsinformatik is...
# 2  Das Vollzeitstudium Wirtschaftsinformatik daue...
# 3  Der Studiengang Wirtschaftsinformatik wird hau...
# 4  Es müssen insgesamt 210 ECTS-Punkte erworben w...
